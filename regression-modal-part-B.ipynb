# %% [markdown]
# ## B. Predicting Concrete Compressive Strength Using Deep Learning: A Regression Approach with Keras (With Normalize data)

# %%
import pandas as pd
import numpy as np
import keras
# Out:
# 2025-01-15 13:05:53.287455: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
filepath='data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
# Splitting data into predictors and target
concrete_data_columns = concrete_data.columns
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# ### Normalize Data

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# ###  Import Keras Packages

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# ### Build a Neural Network

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))  # Input layer
    model.add(Dense(10, activation='relu'))  # One hidden layer with 10 nodes and ReLU activation
    model.add(Dense(1))  # Output layer for regression (single output node)
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')  # Adam optimizer and MSE loss function
    return model

# %% [markdown]
# ### Train and Test the Network

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=42)

# build the model
baseline_model = regression_model()

# Fit the model on the training data
baseline_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 23/23 - 1s - 44ms/step - loss: 1590.3870 - val_loss: 1492.7731
# Epoch 2/50
# 23/23 - 0s - 20ms/step - loss: 1571.6342 - val_loss: 1475.3185
# Epoch 3/50
# 23/23 - 0s - 12ms/step - loss: 1553.2914 - val_loss: 1458.1273
# Epoch 4/50
# 23/23 - 0s - 6ms/step - loss: 1534.7971 - val_loss: 1441.1594
# Epoch 5/50
# 23/23 - 0s - 5ms/step - loss: 1516.5907 - val_loss: 1423.4796
# Epoch 6/50
# 23/23 - 0s - 15ms/step - loss: 1497.7781 - val_loss: 1405.8965
# Epoch 7/50
# 23/23 - 0s - 6ms/step - loss: 1478.6757 - val_loss: 1388.3418
# Epoch 8/50
# 23/23 - 0s - 14ms/step - loss: 1459.3467 - val_loss: 1370.0854
# Epoch 9/50
# 23/23 - 0s - 14ms/step - loss: 1439.5526 - val_loss: 1351.7004
# Epoch 10/50
# 23/23 - 0s - 13ms/step - loss: 1419.2812 - val_loss: 1332.7300
# Epoch 11/50
# 23/23 - 0s - 19ms/step - loss: 1398.4980 - val_loss: 1313.4686
# Epoch 12/50
# 23/23 - 0s - 4ms/step - loss: 1377.4414 - val_loss: 1293.3190
# Epoch 13/50
# 23/23 - 0s - 9ms/step - loss: 1354.8853 - val_loss: 1272.9685
# Epoch 14/50
# 23/23 - 0s - 4ms/step - loss: 1332.2028 - val_loss: 1251.3484
# Epoch 15/50
# 23/23 - 0s - 6ms/step - loss: 1308.5929 - val_loss: 1229.3196
# Epoch 16/50
# 23/23 - 0s - 4ms/step - loss: 1284.0677 - val_loss: 1206.9661
# Epoch 17/50
# 23/23 - 0s - 7ms/step - loss: 1259.3107 - val_loss: 1183.6638
# Epoch 18/50
# 23/23 - 0s - 7ms/step - loss: 1233.3441 - val_loss: 1160.2230
# Epoch 19/50
# 23/23 - 0s - 12ms/step - loss: 1207.5397 - val_loss: 1135.8300
# Epoch 20/50
# 23/23 - 0s - 4ms/step - loss: 1180.5674 - val_loss: 1111.5804
# Epoch 21/50
# 23/23 - 0s - 9ms/step - loss: 1153.8005 - val_loss: 1086.9242
# Epoch 22/50
# 23/23 - 0s - 11ms/step - loss: 1126.6121 - val_loss: 1061.7854
# Epoch 23/50
# 23/23 - 0s - 3ms/step - loss: 1098.8765 - val_loss: 1036.3281
# Epoch 24/50
# 23/23 - 0s - 7ms/step - loss: 1071.0519 - val_loss: 1010.9453
# Epoch 25/50
# 23/23 - 0s - 6ms/step - loss: 1043.1571 - val_loss: 985.6521
# Epoch 26/50
# 23/23 - 0s - 6ms/step - loss: 1015.0410 - val_loss: 960.3406
# Epoch 27/50
# 23/23 - 0s - 7ms/step - loss: 986.8067 - val_loss: 935.1179
# Epoch 28/50
# 23/23 - 0s - 6ms/step - loss: 958.9943 - val_loss: 909.5371
# Epoch 29/50
# 23/23 - 0s - 5ms/step - loss: 930.9824 - val_loss: 883.6281
# Epoch 30/50
# 23/23 - 0s - 6ms/step - loss: 902.5197 - val_loss: 858.7153
# Epoch 31/50
# 23/23 - 0s - 6ms/step - loss: 875.3093 - val_loss: 833.0666
# Epoch 32/50
# 23/23 - 0s - 6ms/step - loss: 847.5390 - val_loss: 808.0295
# Epoch 33/50
# 23/23 - 0s - 9ms/step - loss: 820.3436 - val_loss: 783.6267
# Epoch 34/50
# 23/23 - 0s - 10ms/step - loss: 794.0619 - val_loss: 758.8362
# Epoch 35/50
# 23/23 - 0s - 7ms/step - loss: 767.9101 - val_loss: 734.3062
# Epoch 36/50
# 23/23 - 0s - 12ms/step - loss: 741.8870 - val_loss: 710.7316
# Epoch 37/50
# 23/23 - 0s - 14ms/step - loss: 716.6794 - val_loss: 687.1992
# Epoch 38/50
# 23/23 - 0s - 5ms/step - loss: 691.8241 - val_loss: 664.3594
# Epoch 39/50
# 23/23 - 0s - 5ms/step - loss: 667.6158 - val_loss: 641.7571
# Epoch 40/50
# 23/23 - 0s - 7ms/step - loss: 644.5234 - val_loss: 619.2410
# Epoch 41/50
# 23/23 - 0s - 13ms/step - loss: 620.7739 - val_loss: 598.5768
# Epoch 42/50
# 23/23 - 0s - 12ms/step - loss: 598.9611 - val_loss: 577.7549
# Epoch 43/50
# 23/23 - 0s - 12ms/step - loss: 577.3361 - val_loss: 557.4236
# Epoch 44/50
# 23/23 - 0s - 6ms/step - loss: 556.5572 - val_loss: 537.8975
# Epoch 45/50
# 23/23 - 0s - 7ms/step - loss: 536.2626 - val_loss: 519.2442
# Epoch 46/50
# 23/23 - 0s - 7ms/step - loss: 517.1310 - val_loss: 500.9222
# Epoch 47/50
# 23/23 - 0s - 11ms/step - loss: 498.7091 - val_loss: 483.8829
# Epoch 48/50
# 23/23 - 0s - 10ms/step - loss: 481.2176 - val_loss: 466.8640
# Epoch 49/50
# 23/23 - 0s - 5ms/step - loss: 463.9941 - val_loss: 451.1230
# Epoch 50/50
# 23/23 - 0s - 6ms/step - loss: 448.1627 - val_loss: 435.4671

# %% [markdown]
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength.

# %%
predictions = baseline_model.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
mse = mean_squared_error(y_test, predictions)
mean = np.mean(mse)
standard_deviation = np.std(mse)
print(mean, standard_deviation)
# Out:
# 435.4670801092232 0.0

# %% [markdown]
# Create a list of 50 mean squared errors and report the mean and the standard deviation of the mean squared errors.

# %%
# Function to train and evaluate the model
def train_and_evaluate(model, predictors_norm, target):
    # Split the data into training and test sets (30% test set)
    X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=None)
    
    # Train the model on the training data
    model.fit(X_train, y_train, epochs=50, verbose=0)  # Train for 50 epochs
    
    # Predict on the test set
    predictions = model.predict(X_test)
    
    # Compute the mean squared error
    mse = mean_squared_error(y_test, predictions)
    return mse

# %%
# Build the model
model = regression_model()

# Repeat the process 50 times
mse_list = [train_and_evaluate(model, predictors_norm, target) for _ in range(50)]
mse_list
# Compute the mean and standard deviation of the MSEs
mean_mse = np.mean(mse_list)
std_mse = np.std(mse_list)

# Report the results
print(f"Mean of Mean Squared Errors: {mean_mse}")
print(f"Standard Deviation of Mean Squared Errors: {std_mse}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean of Mean Squared Errors: 48.01764321329418
# Standard Deviation of Mean Squared Errors: 49.83340421816451

# %% [markdown]
# The normalized data yields a more accurate model with a mean MSE approximately 7.59% lower than the non-normalized data.
